# %%
'''
    Movie Ticket Booking
 Input age, student status, time of show.
 Apply discounts based on:
o Age (<12, >60)
o Time (morning shows)
o Student ID (DCPG/___/24.
o _ apply digit.
    '''

# %%
age = int(input('Enter your age : '))
student_id = input('Enter your student id : ')

choice_of_time = int(input('1 for 06:00 AM , 2 for 08:30 AM, 3 for  10:45 AM , other for another show not morning show Enter your choice : ')) 
if choice_of_time==1:
    time = '06:00 AM'
elif choice_of_time == 2:
    time ='08:30 AM'
elif choice_of_time == 3:
    time = '10:45 AM'
else:
    time = input('Enter your time of show : ')
morning_show = ['06:00 AM','08:30 AM','10:45 AM']

if (age <12) :
    print('You have gotten 6% discount of your ticket for below 12 age  . ')
elif (age>60):
    print('You have gotten 5% discount of your ticket for upper 60 age. ')
else:
    print('Sorry we do not provide any discount for age.')
    



if time in morning_show: 
    print('You have gotten 2% discount of your ticket for morning show. ')
else:
    print('Sorry we do not provide any discount for time of show.')


if student_id[0]=='D':
    if student_id[1]=='C':
        if student_id[2]=='P' :
            if student_id[3]=='G':
                if student_id[len(student_id)-1]=='4' :
                    if student_id[len(student_id)-2]=='2':
                        print('You have gotten 4% discount of your ticket for this student id. ')
# Out:
# Enter your age : 10
# Enter your student id : km
# 1 for 06:00 AM , 2 for 08:30 AM, 3 for  10:45 AM , other for another show not morning show Enter your choice : 1
# You have gotten 6% discount of your ticket for below 12 age  .
# You have gotten 2% discount of your ticket for morning show.
