# %%
'''
    Number to Words Converter (0-9999)
 Input an integer from 0 to 9999.
 Convert to words using if-elif-else only (no built-ins or libraries).
    '''
# Out:
# '\n    Number to Words Converter (0-9999)\n\uf0b7 Input an integer from 0 to 9999.\n\uf0b7 Convert to words using if-elif-else only (no built-ins or libraries).\n    '

# %%
dict = { '0' : 'Zero' ,
        '1' : 'one' ,
        '2' : 'Two' , 
        '3' : 'Three',
       '4' : 'Four',
       '5' : 'Five',
       '6' : 'Six',
       '7' : 'Seven',
       '8' : 'Eight',
       '9' : 'Nine',
       '10' : 'Ten',
       '11' : 'Eleven',
       '12' : 'Twelve',
       '13' : 'Thirteen',
       '14' : 'Fourteen',
        '15' : 'Fifteen',
        '16' : 'Sixteen',
        '17' : 'Seventeen',
        '18' : 'Eighteen',
        '19' : 'Nineteen',
       '20' : 'Twenty',
       '30' : 'Thirty',
       '40' : 'Fourty',
       '50': 'Fifty',
       '60' : 'sixty',
       '70' : 'Seventy',
       '80' : 'Eighty',
       '90' : 'Ninty'}
input1 = int(input('Enter the number from 0 to 9999 : '))
def count(n):
    c = 0
    l = []
    while n > 0 :
        r = n % 10
        l.append(str(r))
        c += 1
        n = n // 10
    return l , c
a , b = count(input1)

if input1 == 0:
    print(dict[str(input1)])

else :
    
    if b==1:
        print(dict[str(input1)])


    elif b==2:
        if a[1] == '1':
            s = a[1] + a[0]
            
            l2 = []
            if s in dict:
                
                l2.append(dict[s])


            print(l2[0])
        elif a[0] == '0':
            s1 = a[1] + a[0]
            print(dict[s1])

        else:
            list1 = a[1] + '0'


            a[1] = list1
            l1 = []
            for i in range(len(a)):
                if a[i] in dict:

                   l1.append(dict[a[i]])

            print((l1[len(l1)-1]) , l1[(len(l1)-2)])
    elif b==3:
        if a[1] == '1':
            s = a[1] + a[0]

            l2 = []
            if s in dict:

                l2.append(dict[s])
            l2.append(dict[a[2]])

            print(l2[1] , 'hundred' , l2[0])
        elif (a[0] == '0') and (a[1] == '0') :

            print(dict[a[2]] , 'hundred')

        else :       
            list1 = a[1] + '0'

            a[1] = list1
            l1 = []

            for i in range(len(a)):
                if a[i] in dict:

                   l1.append(dict[a[i]])

            print((l1[len(l1)-1]) ,'hundred' , l1[(len(l1)-2)],l1[(len(l1)-3)])
    elif b==4:
        if a[1] == '1':
            s = a[1] + a[0]

            l2 = []
            if s in dict:

                l2.append(dict[s])
            l2.append(dict[a[2]])
            l2.append(dict[a[3]])

            print(l2[2] , 'thousand' , l2[1] , 'hundred' , l2[0])
        elif (a[0] == '0') and (a[1] == '0') and (a[2] == '0'):

            print(dict[a[3]] , 'thousand')
        else:
            list1 = a[1] + '0'

            a[1] = list1
            l1 = []
            for i in range(len(a)):
                if a[i] in dict:

                   l1.append(dict[a[i]])

            print((l1[len(l1)-1]) ,'thousand' , l1[(len(l1)-2)], 'hundred' , l1[(len(l1)-3)] , l1[(len(l1)-4)] )
# Out:
# Enter the number from 0 to 9999 : 3695
# Three thousand Six hundred Ninty Five
