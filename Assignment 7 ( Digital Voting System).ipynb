# %%
''' 
    Digital Voting System
 Input age and citizenship.
 Determine:
o If eligible to vote
o If eligible to stand for election (age 25+)
o If ineligible, give reason
    '''

# %%
def vote (age , citizen):
    if (age >= 18) and (citizen == f'{citizen}'):
        print('You are eligible for voting ')
        if (age > 25):
            print('You are eligible to stand for election ')
        else:
            print('you are not 25+ . So You are not eligible to stand for election')
    elif (age):
        print('you are not 18 . You are not eligible for voting ')
n1 = int(input('Enter your age : '))
n2 = input('Enter you citizenship :')     
vote(n1,n2)
# Out:
# Enter your age : 26
# Enter you citizenship :india
# You are eligible for voting
# You are eligible to stand for election
