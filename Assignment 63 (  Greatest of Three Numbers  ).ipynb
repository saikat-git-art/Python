# %%
'''
Greatest of Three Numbers
Write a function greatest_of_three(a,b,c) that returns the largest of three numbers. Call the
function with different sets of numbers.

'''

# %%
def got(a,b,c):
    if (a<b<c) or (b<a<c):
        print('Greatest number is : ',c)
    elif (b<c<a) or (c<b<a):
        print('Greatest number is : ',a)
    elif (a<c<b) or (c<a<b):
        print('Greatest number is : ',b)
    
    
n1 = int(input('Enter 1st number : '))
n2 = int(input('Enter 2nd number : '))
n3 = int(input('Enter 3rd number : '))
got(n1,n2,n3)
# Out:
# Enter 1st number : 0
# Enter 2nd number : 1
# Enter 3rd number : 2
# Greatest number is :  2
