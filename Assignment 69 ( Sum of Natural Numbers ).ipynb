# %%
'''
Sum of Natural Numbers
Write a recursive function sum_natural(n) which returns the sum of the first n natural
numbers.

'''

# %%
n = int(input('Enter numer : '))
def sum(n):
    if n ==1:
        return 1
    else:
        s = n +sum(n-1)
        return s
    
sum(n)
# Out:
# Enter numer : 3
# 6
