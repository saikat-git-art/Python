# %%
'''
Custom Sorting by Frequency then Value
Given a list of integers, sort them first by their frequency (ascending) and then by their value
(descending) if frequencies match.
Example: [4,4,2,2,3,3,3,1] → [1,4,4,2,2,3,3,3].

'''

# %%
a = []
n = int(input('How many numbers will you take in the list ? '))
for i in range(n):
    k = int(input('Enter value : '))
    a.append(k)
print(a)
b = []
for i in range(len(a)):
    c =0
    for j in range(len(a)):
        if a[i] == a[j]:
            c = c+1
    
    m = (a[i],c)
    b.append(m)

k = []
for i in range(len(b)):
    if b[i] in b[0:i]:
        continue
    else:
        k.append(b[i])
       
 

    
l = []    
for i in range(len(k)):
    for j in range(len(k)):
        if k[j][1] == i:
            for d in range(k[j][1]):
                l.append(k[j][0])
print(l)
# Out:
# How many numbers will you take in the list ? 8
# Enter value : 4
# Enter value : 4
# Enter value : 2
# Enter value : 2
# Enter value : 3
# Enter value : 3
# Enter value : 3
# Enter value : 1
# [4, 4, 2, 2, 3, 3, 3, 1]
# [1, 4, 4, 2, 2, 3, 3, 3]
