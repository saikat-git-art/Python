# %%
'''
    Hotel Room Booking System
 Input room type, days, number of people.
 Apply:
o Rates based on room type
o Discounts for long stays
o Extra charge for extra people

    '''

# %%
rate = {
    '2 bed room' : 15000,
    '4 bed room' : 10000,
    '6 bed room' : 7000
}
discount = {
    'for 5 days' : ' 2%' ,
    'for 7 days' : '4%' ,
    'for 10 days' : '5%',
    'for 15 Days' : '7%'
}
extra_charge = {
    '1 extra people' : 300,
    '2 extra people' : 500,
    '3 extra people' : 700,
    '4 extra people' : 1000,
    '5 extra people' : 12000,
    '6 extra people' : 15000
}

ch = int(input(f" 1 for 2 bed room , 2 for 4 bed room , 3 for 6 bed room .. {rate} . Please enter your room type choice to see the list "))

print(f'please see the list for extra charge for extra people {extra_charge}')
people = int(input('How many people will stay in a room'))

if ch == 1:
    print(f'Thank you for booking 2 bedding room ')
    if people == 3:
        print(extra_charge['1 extra people'],'extra amount you will pay')
    else:
        if people == 4:
            print(extra_charge['2 extra people'],'extra amount you will pay')
        else:
            if people == 5:
                print(extra_charge['3 extra people'],'extra amount you will pay')
            else:
                if people == 6:
                    print(extra_charge['4 extra people'],'extra amount you will pay')
                else:
                    if people == 7:
                        print(extra_charge['5 extra people'],'extra amount you will pay')
                    else:
                        if people >= 8:
                            print(extra_charge['6 extra people'],'extra amount you will pay')
elif ch ==2:
    print('Thank you for booking 4 bedding room ')
    if people == 5:
        print(extra_charge['1 extra people'],'extra amount you will pay')
    else:
        if people == 6:
            print(extra_charge['2 extra people'],'extra amount you will pay')
        else:
            if people == 7:
                print(extra_charge['3 extra people'],'extra amount you will pay')
            else:
                if people == 8:
                    print(extra_charge['4 extra people'],'extra amount you will pay')
                else:
                    if people == 9:
                        print(extra_charge['5 extra people'],'extra amount you will pay')
                    else:
                        if people >= 10:
                            print(extra_charge['6 extra people'],'extra amount you will pay')
elif ch ==3:
    print('Thank you for booking 6 bedding room ')
    if people == 7:
        print(extra_charge['1 extra people'],'extra amount you will pay')
    else:
        if people == 8:
            print(extra_charge['2 extra people'],'extra amount you will pay')
        else:
            if people == 9:
                print(extra_charge['3 extra people'],'extra amount you will pay')
            else:
                if people == 10:
                    print(extra_charge['4 extra people'],'extra amount you will pay')
                else:
                    if people == 11:
                        print(extra_charge['5 extra people'],'extra amount you will pay')
                    else:
                        if people >= 12:
                            print(extra_charge['6 extra people'],'extra amount you will pay')
    
    
print(f'See discounts for long stays {discount} . After you select days')


days = int(input('how many days will you stay in our hotel '))
print(f'you book the room for {days} days')
if days== 5:
    print(discount['for 5 days'],' discount you have gotten for booking room in our hotel' )
elif days == 7:
    print(discount['for 7 days'],' discount you have gotten for booking room in our hotel  ' )
elif days == 10:
    print(discount['for 10 days'],' discount you have gotten for booking room in our hotel  ' )
elif days == 15:
    print(discount['for 15 days'],' discount you have gotten for booking room in our hotel  ' )
# Out:
#  1 for 2 bed room , 2 for 4 bed room , 3 for 6 bed room .. {'2 bed room': 15000, '4 bed room': 10000, '6 bed room': 7000} . Please enter your room type choice to see the list 2
# please see the list for extra charge for extra people {'1 extra people': 300, '2 extra people': 500, '3 extra people': 700, '4 extra people': 1000, '5 extra people': 12000, '6 extra people': 15000}
# How many people will stay in a room3
# Thank you for booking 4 bedding room
# See discounts for long stays {'for 5 days': ' 2%', 'for 7 days': '4%', 'for 10 days': '5%', 'for 15 Days': '7%'} . After you select days
# how many days will you stay in our hotel 11
# you book the room for 11 days
