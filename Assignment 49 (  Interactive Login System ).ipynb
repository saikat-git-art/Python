# %%
'''
Interactive Login System
 Store username-password pairs in a dictionary
 Allow 3 login attempts
 On successful login, show welcome message
 On failure, lock out the user

'''

# %%
user_pass = {
    'Saikat' : 'Saikat@10',
    'Rakesh' : 'Rak$593',
    'Dinesh' : 'Dine&7803'
}
print('  LOGIN YOUR ACCOUNT ')


for i in range(4):
    if i == 2:
        print('This is the last chance')
    elif i == 3:
        print('Block your account')
        break
    username = input('Enter your username : ')
    password = input('Enter your password : ')
    
    if username in user_pass:
        if user_pass[username] == password:
            print('Login Succesfully \nwelcome')
            break
        else :
            print('username is correct ')
            print('Please enter correct password ')
              
           
    else:
        if i < 2:
            print('Please enter correct username')
            print('Login process will be start from first')
# Out:
#   LOGIN YOUR ACCOUNT
# Enter your username : ss
# Enter your password : ss
# Please enter correct username
# Login process will be start from first
# Enter your username : ss
# Enter your password : ss
# Please enter correct username
# Login process will be start from first
# This is the last chance
# Enter your username : ss
# Enter your password : ss
# Block your account
